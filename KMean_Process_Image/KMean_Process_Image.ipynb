# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist

# %%
img = plt.imread('Image/a.jpg')
width = img.shape[0]
heigth = img.shape[1]
deepth = img.shape[2]

img = img.reshape(width*heigth, deepth)

img2 = np.zeros_like(img)

#Algorithm Kmean
kmeans = KMeans(n_clusters=4).fit(img)
labels = kmeans.predict(img)
clusters = kmeans.cluster_centers_

for i in range(len(img2)):
    img2[i] = clusters[labels[i]]

img2 = img2.reshape((width, heigth, deepth))

plt.imshow(img2)
plt.show()

# %%
distortions = []
inertias = []
mapping1 = []
mapping2 = []
K = range(1, 10)

for k in K:
    #Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(img)
    kmeanModel.fit(img)

    distortions.append(sum(np.min(cdist(img, kmeanModel.cluster_centers_, 
                                        'euclidean'),axis=2))/width)
    inertias.append(kmeanModel.inertia_)
    
    mapping1[k] = sum(np.min(cdist(img, kmeanModel.cluster_centers_,
                                   'euclidean'),axis=1)) / width
    mapping2[k] = kmeanModel.inertia_

# %%
img.shape
# Out:
# (368016, 3)
